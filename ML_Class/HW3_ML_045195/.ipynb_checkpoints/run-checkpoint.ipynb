# %%
# %run keras_dnn.py
# Out:
# Reading bat data...
# EOF Reached
# Done reading
# num_class 3
# model_output_shape: (None, 100, 3)
# train_set_y_shape: (100, 3)
# train_set_x_shape: (100, 3)
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 100, 100)          400
# _________________________________________________________________
# dense_5 (Dense)              (None, 100, 100)          10100
# _________________________________________________________________
# dense_6 (Dense)              (None, 100, 100)          10100
# _________________________________________________________________
# dense_7 (Dense)              (None, 100, 3)            303
# ...
# Total params: 20,903
# Trainable params: 20,903
# Non-trainable params: 0
# _________________________________________________________________
# (100, 3)
# Epoch 1/2000
# ...
